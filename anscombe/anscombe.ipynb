# %%
import pandas as pd

# %%
Anscombe_quartet_data=pd.read_csv('Anscombe_quartet_data.csv')

# %%
Anscombe_quartet_data
# Out:
#     x123     y1    y2     y3    x4     y4
# 0   10.0   8.04  9.14   7.46   8.0   6.58
# 1    8.0   6.95  8.14   6.77   8.0   5.76
# 2   13.0   7.58  8.74  12.74   8.0   7.71
# 3    9.0   8.81  8.77   7.11   8.0   8.84
# 4   11.0   8.33  9.26   7.81   8.0   8.47
# 5   14.0   9.96  8.10   8.84   8.0   7.04
# 6    6.0   7.24  6.13   6.08   8.0   5.25
# 7    4.0   4.26  3.10   5.39  19.0  12.50
# 8   12.0  10.84  9.13   8.15   8.0   5.56
# 9    7.0   4.82  7.26   6.42   8.0   7.91
# 10   5.0   5.68  4.74   5.73   8.0   6.89

# %%
Anscombe_quartet_data.mean()
# Out:
# x123    9.000000
# y1      7.500909
# y2      7.500909
# y3      7.500000
# x4      9.000000
# y4      7.500909
# dtype: float64

# %%
Anscombe_quartet_data.std()
# Out:
# x123    3.316625
# y1      2.031568
# y2      2.031657
# y3      2.030424
# x4      3.316625
# y4      2.030579
# dtype: float64

# %% [markdown]
# Maybe the dataset provided by Kaggle is a bit rounded up?

# %%
Anscombe_quartet_data.plot(kind='scatter',y='y1',x='x123')
# Out:
# <Axes: xlabel='x123', ylabel='y1'>

# %%
pd.plotting.bootstrap_plot(Anscombe_quartet_data.y1,size=7,samples=50)

# %%
Anscombe_quartet_data.plot(kind='scatter',y='y2',x='x123')
# Out:
# <Axes: xlabel='x123', ylabel='y2'>

# %%
pd.plotting.bootstrap_plot(Anscombe_quartet_data.y2,size=7,samples=50)

# %%
Anscombe_quartet_data.plot(kind='scatter',y='y3',x='x123')
# Out:
# <Axes: xlabel='x123', ylabel='y3'>

# %%
pd.plotting.bootstrap_plot(Anscombe_quartet_data.y3,size=7,samples=50)

# %%
Anscombe_quartet_data.plot(kind='scatter',y='y4',x='x4')
# Out:
# <Axes: xlabel='x4', ylabel='y4'>

# %%
pd.plotting.bootstrap_plot(Anscombe_quartet_data.y4,size=7,samples=50)

# %%
pd.plotting.bootstrap_plot(Anscombe_quartet_data.x4,size=7,samples=50)
